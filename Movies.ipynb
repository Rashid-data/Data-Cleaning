# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("unclean_data.csv")

# %%
df.head()
# Out:
#                                 movie_title  num_critic_for_reviews  duration  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302       NaN
# 2                                   Spectre                     602     148.0
# 3                     The Dark Knight Rises                     813       NaN
# 4                               John Carter                     462     132.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     object
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        ACTOR_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %% [markdown]
# ### Change Inconsistent Column Names

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.columns=df.columns.str.upper()

# %%
df
# Out:
#                                    MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %% [markdown]
# ### Renaming the columns

# %%
df.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df.rename(columns = {'MOVIE_TITLE':'MOVIE NAME'}, inplace=True)

# %%
df.rename(columns = {'NUM_CRITIC_FOR_REVIEWS':'CRITIC REVIEWS'}, inplace=True)

# %%
df.rename(columns = {'DURATION':'TIME'}, inplace=True)

# %%
df.rename(columns = {'DIRECTOR_FACEBOOK_LIKES':'DIRECTOR FB LIKES'}, inplace=True)

# %%
df.rename(columns = {'ACTOR_3_FACEBOOK_LIKES':'ACTOR FB LIKES'}, inplace=True)

# %%
df.rename(columns = {'ACTOR_1_FACEBOOK_LIKES':'ACTRESS FB LIKES'}, inplace=True)

# %%
df.rename(columns = {'NUM_VOTED_USERS':'NUM OF VOTED USERS'}, inplace=True)

# %%
df.rename(columns = {'CAST_TOTAL_FACEBOOK_LIKES':'CAST FB LIKES'}, inplace=True)

# %%
df.rename(columns = {'FACENUMBER_IN_POSTER':'FACE IN POSTER'}, inplace=True)

# %%
df.rename(columns = {'NUM_USER_FOR_REVIEWS':'NUM OF USER REVIEWS'}, inplace=True)

# %%
df.rename(columns = {'TITLE_YEAR':'TITLE YEAR'}, inplace=True)

# %%
df.rename(columns = {'ACTOR_2_FACEBOOK_LIKES':'OPPOSITE ACTOR FB LIKES'}, inplace=True)

# %%
df.rename(columns = {'IMDB_SCORE':'IMDb SCORE'}, inplace=True)

# %%
df.rename(columns = {'TITLE_YEAR.1':'TITLE YEAR 1'}, inplace=True)

# %%
df.head()
# Out:
#                                  MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                    Avatar             723  178.0
# 1  Pirates of the Caribbean: At World's End             302    NaN
# 2                                   Spectre             602  148.0
# 3                     The Dark Knight Rises             813    NaN
# 4                               John Carter             462  132.0
#
#   DIRECTOR FB LIKES  ACTOR FB LIKES  ACTRESS FB LIKES      GROSS  \
# 0                10             855              1000  760505847
# 1               563            1000             40000  309404152
# 2                20             161             11000  200074175
# 3             22000           23000             27000  448130642
# 4             "475"             530               640   73058679
#
#    NUM OF VOTED USERS  CAST FB LIKES  FACE IN POSTER  NUM OF USER REVIEWS  \
# 0            886204.0         4834.0             NaN                 3054
# ...

# %% [markdown]
# ### Handling Missing Data

# %%
df.isnull().sum()
# Out:
# MOVIE NAME                 0
# CRITIC REVIEWS             0
# TIME                       3
# DIRECTOR FB LIKES          2
# ACTOR FB LIKES             0
# ACTRESS FB LIKES           0
# GROSS                      0
# NUM OF VOTED USERS         1
# CAST FB LIKES              2
# FACE IN POSTER             5
# NUM OF USER REVIEWS        0
# BUDGET                     0
# TITLE YEAR                 0
# OPPOSITE ACTOR FB LIKES    1
# IMDb SCORE                 0
# TITLE YEAR 1               7
# dtype: int64

# %%
# Columns with NAN using True/False
# False means it doesn't have a NAN
df.isnull().any()
# Out:
# MOVIE NAME                 False
# CRITIC REVIEWS             False
# TIME                        True
# DIRECTOR FB LIKES           True
# ACTOR FB LIKES             False
# ACTRESS FB LIKES           False
# GROSS                      False
# NUM OF VOTED USERS          True
# CAST FB LIKES               True
# FACE IN POSTER              True
# NUM OF USER REVIEWS        False
# BUDGET                     False
# TITLE YEAR                 False
# OPPOSITE ACTOR FB LIKES     True
# IMDb SCORE                 False
# TITLE YEAR 1                True
# dtype: bool

# %%
# For entire DataFrame
df.isnull().any().any()
# Out:
# True

# %%
# Total Number of Missing NA
df.isnull().sum().sum()
# Out:
# 21

# %% [markdown]
# ### Removing Duplicates

# %%
df.duplicated('MOVIE NAME').sum()
# Out:
# 1

# %%
df.drop_duplicates('MOVIE NAME', inplace=True)

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302    NaN
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813    NaN
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324    NaN
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %% [markdown]
# ##### Adding A Default Value or Filling the Missing Data

# %%
# Fill it with the mean
df['TIME'].mean()
# Out:
# 151.7

# %%
df['TIME'] = df['TIME'].fillna(df['TIME'].mean())

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302  151.7
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813  151.7
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324  151.7
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %%
df=df.fillna(0)

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302  151.7
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813  151.7
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324  151.7
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %% [markdown]
# ### Dropping Unnecessary columns

# %%
df.drop(columns='TITLE YEAR 1', inplace=True)

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302  151.7
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813  151.7
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324  151.7
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MOVIE NAME               13 non-null     object
#  1   CRITIC REVIEWS           13 non-null     int64
#  2   TIME                     13 non-null     float64
#  3   DIRECTOR FB LIKES        13 non-null     object
#  4   ACTOR FB LIKES           13 non-null     int64
#  5   ACTRESS FB LIKES         13 non-null     int64
#  6   GROSS                    13 non-null     int64
#  7   NUM OF VOTED USERS       13 non-null     float64
#  8   CAST FB LIKES            13 non-null     float64
#  9   FACE IN POSTER           13 non-null     float64
#  10  NUM OF USER REVIEWS      13 non-null     int64
#  11  BUDGET                   13 non-null     int64
#  12  TITLE YEAR               13 non-null     int64
#  13  OPPOSITE ACTOR FB LIKES  13 non-null     float64
# ...

# %% [markdown]
# ### Convert Datatypes

# %%
df.dtypes
# Out:
# MOVIE NAME                  object
# CRITIC REVIEWS               int64
# TIME                       float64
# DIRECTOR FB LIKES           object
# ACTOR FB LIKES               int64
# ACTRESS FB LIKES             int64
# GROSS                        int64
# NUM OF VOTED USERS         float64
# CAST FB LIKES              float64
# FACE IN POSTER             float64
# NUM OF USER REVIEWS          int64
# BUDGET                       int64
# TITLE YEAR                   int64
# OPPOSITE ACTOR FB LIKES    float64
# IMDb SCORE                 float64
# dtype: object

# %%
#changing gross datatype
df.GROSS.astype(float).dtypes
# Out:
# dtype('float64')

# %%
#changing directors datatype
# Remove double quotes from the column
df['DIRECTOR FB LIKES'] = df['DIRECTOR FB LIKES'].str.replace('"', '')

# Convert the column to integers
df['DIRECTOR FB LIKES'] = df['DIRECTOR FB LIKES'].astype(float)

# Check the data types after conversion
print(df['DIRECTOR FB LIKES'].dtypes)
# Out:
# float64

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302  151.7
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813  151.7
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324  151.7
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %%
df=df.fillna(0)

# %%
df
# Out:
#                                     MOVIE NAME  CRITIC REVIEWS   TIME  \
# 0                                       Avatar             723  178.0
# 1     Pirates of the Caribbean: At World's End             302  151.7
# 2                                      Spectre             602  148.0
# 3                        The Dark Knight Rises             813  151.7
# 4                                  John Carter             462  132.0
# 5                                 Spider-Man 3             392  156.0
# 6                                      Tangled             324  151.7
# 7                      Avengers: Age of Ultron             635  141.0
# 9       Harry Potter and the Half-Blood Prince             375  153.0
# 10          Batman v Superman: Dawn of Justice             673  183.0
# 11                            Superman Returns             434  169.0
# 12                           Quantum of Solace             403  106.0
# ...

# %%
df['DIRECTOR FB LIKES']=df['DIRECTOR FB LIKES'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 13
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MOVIE NAME               13 non-null     object
#  1   CRITIC REVIEWS           13 non-null     int64
#  2   TIME                     13 non-null     float64
#  3   DIRECTOR FB LIKES        13 non-null     int32
#  4   ACTOR FB LIKES           13 non-null     int64
#  5   ACTRESS FB LIKES         13 non-null     int64
#  6   GROSS                    13 non-null     int64
#  7   NUM OF VOTED USERS       13 non-null     float64
#  8   CAST FB LIKES            13 non-null     float64
#  9   FACE IN POSTER           13 non-null     float64
#  10  NUM OF USER REVIEWS      13 non-null     int64
#  11  BUDGET                   13 non-null     int64
#  12  TITLE YEAR               13 non-null     int64
#  13  OPPOSITE ACTOR FB LIKES  13 non-null     float64
# ...

# %%
# Export DataFrame to a CSV file
df.to_csv('Movies_data.csv', index=False)
