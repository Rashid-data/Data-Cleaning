# %% [markdown]
# # Netflix Data Cleaning

# %%
#Read data with pandas
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix.csv")

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingdescription     59
# rating_level           0
# release_year           0
# user_rating_score    395
# user_rating_size       0
# dtype: int64

# %%
data[data["ratingdescription"].isnull()]
# Out:
#                                                  title rating  \
# 25                                  Marvel's Iron Fist  TV-MA
# 31                               OperaÃ§Ãµes Especiais  TV-MA
# 39                                            Girlboss  TV-MA
# 42                                         Sand Castle  TV-MA
# 44                                        Sandy Wexler  TV-14
# 45                                     O Amor no DivÃ£  TV-MA
# 46                             Stronger Than the World     NR
# 48                                     Happily Married  TV-14
# 49                                             Pandora  TV-MA
# 77                                  Marvel's Iron Fist  TV-MA
# 85                                        Ingobernable  TV-MA
# 93                                            Girlboss  TV-MA
# 94                                       The Discovery  TV-MA
# 95                                         Sand Castle  TV-MA
# ...

# %%
data[data["user_rating_score"].isnull()]
# Out:
#                          title rating  \
# 1          Lucky Number Slevin      R
# 14                  The Hunter      R
# 15       Lottie Dottie Chicken   TV-Y
# 21   Ã“ Pai, Ã“ - Look at This  TV-MA
# 22      Nymphomaniac: Volume 1     NR
# ..                         ...    ...
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 996    The Secret Life of Pets     PG
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                      ratingdescription  rating_level  \
# 1    strong violence, sexual content and adult lang...           100
# 14                         language and brief violence           100
# 15                              Suitable for all ages.            10
# 21   For mature audiences.  May not be suitable for...           110
# 22                      This movie has not been rated.           124
# ..                                                 ...           ...
# ...

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                    ratingdescription  rating_level  \
# 0  crude and sexual humor, language and some drug...            80
# 1  strong violence, sexual content and adult lang...           100
# 2  Parents strongly cautioned. May be unsuitable ...            90
# 3  Parents strongly cautioned. May be unsuitable ...            90
# 4  Parental guidance suggested. May not be suitab...            70
#
#    release_year  user_rating_score  user_rating_size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data.tail()
# Out:
#                        title rating  \
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                      ratingdescription  rating_level  \
# 995  for action/peril, some scary moments and brief...            60
# 996                     for action and some rude humor            60
# 997                             Suitable for all ages.            35
# 998                             Suitable for all ages.            35
# 999                                                NaN            35
#
#      release_year  user_rating_score  user_rating_size
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# ...

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.sample()
# Out:
#                                                  title rating  \
# 137  Minimalism: A Documentary About the Important ...  TV-PG
#
#     ratingdescription  rating_level  release_year  user_rating_score  \
# 137               NaN            70          2016                NaN
#
#      user_rating_size
# 137                82

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingdescription', 'rating_level', 'release_year',
#        'user_rating_score', 'user_rating_size'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingdescription  941 non-null    object
#  3   rating_level       1000 non-null   int64
#  4   release_year       1000 non-null   int64
#  5   user_rating_score  605 non-null    float64
#  6   user_rating_size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingdescription     59
# rating_level           0
# release_year           0
# user_rating_score    395
# user_rating_size       0
# dtype: int64

# %% [markdown]
# ### Loc & ILOC

# %% [markdown]
# ### Selection based on index by loc

# %%
data.loc[(data.rating == "PG-13")]
# Out:
#                             title rating  \
# 0                    White Chicks  PG-13
# 250                  The Waterboy  PG-13
# 251    10 Things I Hate About You  PG-13
# 253  How to Lose a Guy in 10 Days  PG-13
# 254              The Benchwarmers  PG-13
# 255                       Step Up  PG-13
# 257                      Twilight  PG-13
# 273                  Mean Girls 2  PG-13
# 286                    Safe Haven  PG-13
# 300                  The Waterboy  PG-13
# 302           The Wedding Planner  PG-13
# 306                      Twilight  PG-13
# 322                  Mean Girls 2  PG-13
# 335        Trouble with the Curve  PG-13
# 372                 Unconditional  PG-13
#
#                                      ratingdescription  rating_level  \
# 0    crude and sexual humor, language and some drug...            80
# 250               language and some crude sexual humor            80
# 251    adult content, adult language and mild violence            80
# ...

# %%
data.loc[(data.rating == "PG-13") & (data["release_year"] == 2011)]
# Out:
#             title rating                                  ratingdescription  \
# 273  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
# 322  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
#
#      rating_level  release_year  user_rating_score  user_rating_size
# 273            80          2011                NaN                82
# 322            80          2011                NaN                82

# %%
data.loc[(data.rating == "PG-13") | (data["release_year"] == 2011)]
# Out:
#                                                  title    rating  \
# 0                                         White Chicks     PG-13
# 14                                          The Hunter         R
# 66                                       One Tree Hill     TV-14
# 73                     Inside Russia's Toughest Prison     TV-14
# 114                              Friends with Benefits     TV-14
# 213                              Friends with Benefits     TV-14
# 250                                       The Waterboy     PG-13
# 251                         10 Things I Hate About You     PG-13
# 253                       How to Lose a Guy in 10 Days     PG-13
# 254                                   The Benchwarmers     PG-13
# 255                                            Step Up     PG-13
# 257                                           Twilight     PG-13
# 273                                       Mean Girls 2     PG-13
# ...

# %%
data.loc[(data.rating == "TV-14")]
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 489             Rosewood  TV-14
# 491             Quantico  TV-14
# 492            Limitless  TV-14
# 495          No Tomorrow  TV-14
# 499            Greenleaf  TV-14
#
#                                      ratingdescription  rating_level  \
# 2    Parents strongly cautioned. May be unsuitable ...            90
# 3    Parents strongly cautioned. May be unsuitable ...            90
# 5    Parents strongly cautioned. May be unsuitable ...            90
# 7    Parents strongly cautioned. May be unsuitable ...            90
# 9    Parents strongly cautioned. May be unsuitable ...            90
# ..                                                 ...           ...
# 489  Parents strongly cautioned. May be unsuitable ...            90
# ...

# %%
 data.loc[(data.rating == "TV-14") & (data["user_rating_score"] >= 90 )]
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 472   Person of Interest  TV-14
# 474              Scandal  TV-14
# 476             Sherlock  TV-14
# 477      The Client List  TV-14
# 483        The Blacklist  TV-14
#
#                                      ratingdescription  rating_level  \
# 2    Parents strongly cautioned. May be unsuitable ...            90
# 3    Parents strongly cautioned. May be unsuitable ...            90
# 5    Parents strongly cautioned. May be unsuitable ...            90
# 7    Parents strongly cautioned. May be unsuitable ...            90
# 9    Parents strongly cautioned. May be unsuitable ...            90
# ..                                                 ...           ...
# 472  Parents strongly cautioned. May be unsuitable ...            90
# ...

# %%
data.loc[(data.rating == "TV-14")]
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 489             Rosewood  TV-14
# 491             Quantico  TV-14
# 492            Limitless  TV-14
# 495          No Tomorrow  TV-14
# 499            Greenleaf  TV-14
#
#                                      ratingdescription  rating_level  \
# 2    Parents strongly cautioned. May be unsuitable ...            90
# 3    Parents strongly cautioned. May be unsuitable ...            90
# 5    Parents strongly cautioned. May be unsuitable ...            90
# 7    Parents strongly cautioned. May be unsuitable ...            90
# 9    Parents strongly cautioned. May be unsuitable ...            90
# ..                                                 ...           ...
# 489  Parents strongly cautioned. May be unsuitable ...            90
# ...

# %%
data.loc[(data.rating == "TV-14"),["title", "rating_level"]]
# Out:
#                    title  rating_level
# 2         Grey's Anatomy            90
# 3           Prison Break            90
# 5           Supernatural            90
# 7    The Vampire Diaries            90
# 9    Pretty Little Liars            90
# ..                   ...           ...
# 489             Rosewood            90
# 491             Quantico            90
# 492            Limitless            90
# 495          No Tomorrow            90
# 499            Greenleaf            90
#
# [234 rows x 2 columns]

# %% [markdown]
# ### Selection based on index by iloc

# %%
data.iloc[[2,5]]
# Out:
#             title rating                                  ratingdescription  \
# 2  Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# 5    Supernatural  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    rating_level  release_year  user_rating_score  user_rating_size
# 2            90          2016               98.0                80
# 5            90          2016               95.0                80

# %%
data.iloc[[2,5],0:2]
# Out:
#             title rating
# 2  Grey's Anatomy  TV-14
# 5    Supernatural  TV-14

# %%
data.iloc[1:3]
# Out:
#                  title rating  \
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                    ratingdescription  rating_level  \
# 1  strong violence, sexual content and adult lang...           100
# 2  Parents strongly cautioned. May be unsuitable ...            90
#
#    release_year  user_rating_score  user_rating_size
# 1          2006                NaN                82
# 2          2016               98.0                80

# %%
data.iloc[1:3,:-1]
# Out:
#                  title rating  \
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                    ratingdescription  rating_level  \
# 1  strong violence, sexual content and adult lang...           100
# 2  Parents strongly cautioned. May be unsuitable ...            90
#
#    release_year  user_rating_score
# 1          2006                NaN
# 2          2016               98.0

# %% [markdown]
# ## Handling missing values

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                      ratingdescription  rating_level  \
# 0    crude and sexual humor, language and some drug...            80
# 1    strong violence, sexual content and adult lang...           100
# 2    Parents strongly cautioned. May be unsuitable ...            90
# 3    Parents strongly cautioned. May be unsuitable ...            90
# 4    Parental guidance suggested. May not be suitab...            70
# ..                                                 ...           ...
# ...

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingdescription     59
# rating_level           0
# release_year           0
# user_rating_score    395
# user_rating_size       0
# dtype: int64

# %%
data["user_rating_score"].mean()
# Out:
# 84.09421487603306

# %%
int(data["user_rating_score"].mean())
# Out:
# 84

# %%
# Replace NaN with the mean of each column
#df.fillna(df.mean(), inplace=True)

# %%
data.replace(to_replace=np.nan, value=84,inplace=True)

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                      ratingdescription  rating_level  \
# 0    crude and sexual humor, language and some drug...            80
# 1    strong violence, sexual content and adult lang...           100
# 2    Parents strongly cautioned. May be unsuitable ...            90
# 3    Parents strongly cautioned. May be unsuitable ...            90
# 4    Parental guidance suggested. May not be suitab...            70
# ..                                                 ...           ...
# ...

# %%
datad.to_csv('file1.csv')
