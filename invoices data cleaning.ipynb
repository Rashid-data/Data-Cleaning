# %% [markdown]
# # Invoices Data Cleaning

# %% [markdown]
# ## Summary of Dataset

# %% [markdown]
# This Dataset is about people who is odering meals from a restraunt.
# All the participants were ordering meals in a caterogical manner such as Breakfast Lunch & dinner.

# %% [markdown]
# ## Columns Descriptions

# %% [raw]
# Order Id - it contains order id for every participants.
# Date - it contains date of every order.
# Meal Id - it contains meal id for every participants.
# Company Id - it contains company id for every order.
# Date of Meal - it contains date time & GMT for every order.
# Participants - it contains name of the people who has ordered the meal.
# Meal Price - it contains meal price of every ordered meal.
# Type of Meal - it contains category of meal such as breakfast lunch and dinner as per the order time

# %% [markdown]
# ## Issues with the Dataset

# %% [raw]
# 1. Dataset contains wrong Data types -
#    Date have object data types which should be converted into datatime data type.
#    Date of Meal have object data types which should be converted into datatime data type.
#    Type of meal have object data types which should be converted into caterogical data type.
# 2.Dataset have multiple duplicates.
# 3.Dataset have unnecessary columns.

# %%
import pandas as pd

# %%
invoices = pd.read_csv('invoices.csv')

# %%
invoices
# Out:
#                Order Id      Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  27-05-16  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  27-09-18  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  24-08-14  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  12-04-14  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  28-07-15  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...       ...               ...               ...
# 50012  4OMS8ZSA0UX8LHWI  20-09-17  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG  19-03-18  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
# 50014  STJ6QJC30WPRM93H  21-09-17  LMX18PNGWCIMG1QW  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR  28-01-18  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG  06-09-17  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                     Date of Meal                        Participants  \
# ...

# %%
invoices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50017 entries, 0 to 50016
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order Id           50017 non-null  object
#  1   Date               50017 non-null  object
#  2   Meal Id            50017 non-null  object
#  3   Company Id         50017 non-null  object
#  4   Date of Meal       50017 non-null  object
#  5   Participants       50017 non-null  object
#  6   Meal Price         50017 non-null  int64
#  7   Type of Meal       50017 non-null  object
#  8   Heroes Adjustment  50017 non-null  bool
# dtypes: bool(1), int64(1), object(7)
# memory usage: 3.1+ MB

# %%
invoices.columns
# Out:
# Index(['Order Id', 'Date', 'Meal Id', 'Company Id', 'Date of Meal',
#        'Participants', 'Meal Price', 'Type of Meal', 'Heroes Adjustment'],
#       dtype='object')

# %% [markdown]
# ### Converting data types

# %%
invoices['Date'] = invoices['Date'].astype('datetime64')

# %%
invoices['Type of Meal'] = invoices['Type of Meal'].astype('category')

# %%
invoices['Meal Price'] = invoices['Meal Price'].astype('int64')

# %%
invoices.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                    int64
# Type of Meal               category
# Heroes Adjustment              bool
# dtype: object

# %%
invoices.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal  Heroes Adjustment
# 0    Breakfast              False
# 1       Dinner              False
# ...

# %% [markdown]
# ### Removing duplicate

# %%
invoices["Order Id"].duplicated().sum()
# Out:
# 0

# %%
invoices["Date"].duplicated().sum()
# Out:
# 48191

# %%
invoices["Meal Id"].duplicated().sum()
# Out:
# 0

# %%
invoices["Participants"].duplicated().sum()
# Out:
# 22293

# %%
invoices[invoices["Participants"].duplicated()]
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 1      97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 28     N8DEX5RIZLY2TN9S 2018-01-21  O2LFIKLLHXXTWEZL  H3JRC7XX7WJAD4ZO
# 33     E2XFDVKEKUIWPXY9 2018-09-02  XZIY1E85QWMBMVAL  HB25MDZR0MGCQUGX
# 35     FIF56JW8NB30A7H6 2015-08-16  B684C6LB23S0A2IW  HB25MDZR0MGCQUGX
# 36     1SLO340LG6K3VM71 2015-03-01  40UIN6MOZ2GO7O93  HB25MDZR0MGCQUGX
# ...                 ...        ...               ...               ...
# 50004  5DPMPEQ930LJ3HZ7 2017-11-01  T3DS9G6N2Y0AECOP  FC1LJXHNH2883N3Y
# 50007  DSQ3L26W4J1HH2DL 2014-11-05  24E54CJ06WBF66KK  FC1LJXHNH2883N3Y
# 50012  4OMS8ZSA0UX8LHWI 2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR 2018-01-28  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG 2017-06-09  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                     Date of Meal  \
# 1      2018-10-01 20:00:00+02:00
# 28     2018-01-19 13:00:00+01:00
# ...

# %%
invoices[invoices["Company Id"].duplicated()]
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 1      97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ 2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5      AT0R4DFYYAFOC88Q 2014-07-21  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# ...                 ...        ...               ...               ...
# 50012  4OMS8ZSA0UX8LHWI 2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG 2018-03-19  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
# 50014  STJ6QJC30WPRM93H 2017-09-21  LMX18PNGWCIMG1QW  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR 2018-01-28  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG 2017-06-09  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                     Date of Meal  \
# 1      2018-10-01 20:00:00+02:00
# 2      2014-08-23 14:00:00+02:00
# ...

# %%
invoices[invoices["Participants"].duplicated()].head()
# Out:
#             Order Id       Date           Meal Id        Company Id  \
# 1   97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 28  N8DEX5RIZLY2TN9S 2018-01-21  O2LFIKLLHXXTWEZL  H3JRC7XX7WJAD4ZO
# 33  E2XFDVKEKUIWPXY9 2018-09-02  XZIY1E85QWMBMVAL  HB25MDZR0MGCQUGX
# 35  FIF56JW8NB30A7H6 2015-08-16  B684C6LB23S0A2IW  HB25MDZR0MGCQUGX
# 36  1SLO340LG6K3VM71 2015-03-01  40UIN6MOZ2GO7O93  HB25MDZR0MGCQUGX
#
#                  Date of Meal  \
# 1   2018-10-01 20:00:00+02:00
# 28  2018-01-19 13:00:00+01:00
# 33  2018-02-12 20:00:00+01:00
# 35  2015-08-20 09:00:00+02:00
# 36  2015-01-07 07:00:00+01:00
#
#                                          Participants  Meal Price  \
# 1                                    ['David Bishop']          22
# 28  ['Anthony Emerson' 'Kelly Killebrew' 'Lewis Ey...         415
# 33                                  ['Sherika Yates']         326
# 35                 ['Sherika Yates' 'Cheryl Wooster']         486
# ...

# %%
invoices_count = invoices['Participants'].apply(lambda x: x.count('David Bishop')).sum()

# %%
print(invoices_count)
# Out:
# 4

# %%
invoices[invoices["Heroes Adjustment"].duplicated()]
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 1      97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ 2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5      AT0R4DFYYAFOC88Q 2014-07-21  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# ...                 ...        ...               ...               ...
# 50012  4OMS8ZSA0UX8LHWI 2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG 2018-03-19  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
# 50014  STJ6QJC30WPRM93H 2017-09-21  LMX18PNGWCIMG1QW  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR 2018-01-28  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG 2017-06-09  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                     Date of Meal  \
# 1      2018-10-01 20:00:00+02:00
# 2      2014-08-23 14:00:00+02:00
# ...

# %% [markdown]
# ### Removing Unnecessary Columns

# %%
invoices.drop(['Date of Meal', 'Heroes Adjustment'], axis=1, inplace=True)

# %%
invoices
# Out:
#                Order Id       Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ 2014-12-04  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...        ...               ...               ...
# 50012  4OMS8ZSA0UX8LHWI 2017-09-20  1TD5MROATV1NHZ4Y  E4K99D4JR9E40VE1
# 50013  RR0VKJN8V0KHNKGG 2018-03-19  22EX9VZSJKHP4AIP  E4K99D4JR9E40VE1
# 50014  STJ6QJC30WPRM93H 2017-09-21  LMX18PNGWCIMG1QW  E4K99D4JR9E40VE1
# 50015  QHEUIYNC0XQX7GDR 2018-01-28  4U0VH2TGQL30X23X  E4K99D4JR9E40VE1
# 50016  NKHFWT5I2J9LPAPG 2017-06-09  ORWFRT5TUSYGNYG7  E4K99D4JR9E40VE1
#
#                              Participants  Meal Price Type of Meal
# ...

# %%
invoices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50017 entries, 0 to 50016
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Id      50017 non-null  object
#  1   Date          50017 non-null  datetime64[ns]
#  2   Meal Id       50017 non-null  object
#  3   Company Id    50017 non-null  object
#  4   Participants  50017 non-null  object
#  5   Meal Price    50017 non-null  int64
#  6   Type of Meal  50017 non-null  category
# dtypes: category(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Saving dataset

# %%
invoices.to_csv('invoices_data.csv', index=False)
